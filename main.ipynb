# %%
import cv2
import pickle
import cvzone
import numpy as np

#Video feed
cap = cv2.VideoCapture('carPark.mp4')

#Open image
with open('CarParkPos','rb') as f:
    posList = pickle.load(f)
    
width, height = 107, 48

def checkParkingSpace(imgPro):
    
    spaceCounter = 0
    for pos in posList:
        x,y=pos
        
        #Finding if a car is present or not usin pixelcount
        imgCrop = imgPro[y:y+height,x:x+width]
        #Showing all the individual parking lots
        #cv2.imshow(str(x*y),imgCrop)
        count = cv2.countNonZero(imgCrop)
        
        #count number in front of the box
        #empty spaces have very low value compared to the occupied ones
        cvzone.putTextRect(img,str(count),(x,y+height-3), scale=1.5, thickness=2, offset=0)
        
        if count < 800:
            color = (0,255,0)
            thickness = 5
            spaceCounter+=1
        else:
            color = (0,0,255)
            thickness = 2
        cv2.rectangle(img, pos, (pos[0]+width,pos[1]+height), color, thickness)
        
    cvzone.putTextRect(img,f'Free: {spaceCounter}/{len(posList)}',(100,50), scale=4, thickness=5, offset=0, colorR=(0,200,0))
    
while True:
    #Loop it
    if cap.get(cv2.CAP_PROP_POS_FRAMES) == cap.get(cv2.CAP_PROP_FRAME_COUNT):
        cap.set(cv2.CAP_PROP_POS_FRAMES,0)
    success, img = cap.read()
    
    #Thresholding by converting it to grayscale
    imgGray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    imgBlur = cv2.GaussianBlur(imgGray, (3,3), 1)
    imgThreshold = cv2.adaptiveThreshold(imgBlur,255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,25,16)
    #To remove/smoothen the data
    imgMedian = cv2.medianBlur(imgThreshold,5)
    kernel = np.ones((3,3),np.uint8)
    imgDilate = cv2.dilate(imgMedian, kernel, iterations=1)
    
    checkParkingSpace(imgDilate)
    
    #for pos in posList:
        #cv2.rectangle(img, pos, (pos[0]+width,pos[1]+height), (0,0,0), 2)
    
    cv2.imshow("Image",img)
    cv2.imshow("ImageBlur", imgBlur)
    cv2.imshow("ImageThres", imgThreshold)
    cv2.imshow("ImageThres", imgMedian)
    cv2.waitKey(10)

# %% [markdown]
# # Sandbox

# %%
#Count documents
#records.count_documents({})

#Insert 1
park = {
    'lat':'50',
    'lon':'40',
    'spaces':'3',
    'camera':'2'
}
records.insert_one(park)

# %% [markdown]
# # Installations

# %%
pip install pymongo
pip install cv2
pip install os
pip install pickle
pip install cvzone

# %%
pip install dnspython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Parking and MongoDB

# %%
import cv2
import pickle
import cvzone
import numpy as np

from pymongo import MongoClient
client = MongoClient("mongodb+srv://xmoonfieldx:moon@cluster0.ndigt.mongodb.net/?retryWrites=true&w=majority")
db = client.get_database('parking_spaces')
records = db.park

#Video feed
cap = cv2.VideoCapture('carPark.mp4')

#Open image
with open('CarParkPos','rb') as f:
    posList = pickle.load(f)
    
width, height = 107, 48

def checkParkingSpace(imgPro):
    
    spaceCounter = 0
    for pos in posList:
        x,y=pos
        
        #Finding if a car is present or not usin pixelcount
        imgCrop = imgPro[y:y+height,x:x+width]
        #Showing all the individual parking lots
        #cv2.imshow(str(x*y),imgCrop)
        count = cv2.countNonZero(imgCrop)
        
        #count number in front of the box
        #empty spaces have very low value compared to the occupied ones
        cvzone.putTextRect(img,str(count),(x,y+height-3), scale=1.5, thickness=2, offset=0)
        
        if count < 800:
            color = (0,255,0)
            thickness = 5
            spaceCounter+=1
            '''parks = {
                'spaces': spaceCounter
            }'''
        else:
            color = (0,0,255)
            thickness = 2
        cv2.rectangle(img, pos, (pos[0]+width,pos[1]+height), color, thickness)
        
    records.find_one_and_update({'camera':'1'}, {'$set':{'spaces':spaceCounter}})
    cvzone.putTextRect(img,f'Free: {spaceCounter}/{len(posList)}',(100,50), scale=4, thickness=5, offset=0, colorR=(0,200,0))
    
while True:
    #Loop it
    if cap.get(cv2.CAP_PROP_POS_FRAMES) == cap.get(cv2.CAP_PROP_FRAME_COUNT):
        cap.set(cv2.CAP_PROP_POS_FRAMES,0)
    success, img = cap.read()
    
    #Thresholding by converting it to grayscale
    imgGray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    imgBlur = cv2.GaussianBlur(imgGray, (3,3), 1)
    imgThreshold = cv2.adaptiveThreshold(imgBlur,255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,25,16)
    #To remove/smoothen the data
    imgMedian = cv2.medianBlur(imgThreshold,5)
    kernel = np.ones((3,3),np.uint8)
    imgDilate = cv2.dilate(imgMedian, kernel, iterations=1)
    
    checkParkingSpace(imgDilate)
    
    #for pos in posList:
        #cv2.rectangle(img, pos, (pos[0]+width,pos[1]+height), (0,0,0), 2)
    
    cv2.imshow("Image",img)
    cv2.imshow("ImageBlur", imgBlur)
    cv2.imshow("ImageThres", imgThreshold)
    cv2.imshow("ImageThres", imgMedian)
    cv2.waitKey(1)

# %% [markdown]
# # Parking and Firebase

# %%
import cv2
import pickle
import cvzone
import numpy as np
import pyrebase
firebaseConfig = {
    "apiKey": "AIzaSyCXamFpVDF_co3k14wHm7-mJuEIbntYs0Q",
  "authDomain": "entryrecord-dd00d.firebaseapp.com",
  "databaseURL": "https://entryrecord-dd00d-default-rtdb.firebaseio.com",
  "projectId": "entryrecord-dd00d",
  "storageBucket": "entryrecord-dd00d.appspot.com",
  "messagingSenderId": "915960705801",
  "appId": "1:915960705801:web:2fe177610f3d82668099d8",
  "measurementId": "G-0HMNW3R1KT"
}

firebase = pyrebase.initialize_app(firebaseConfig)

db = firebase.database()

#Retrieve data
n = db.child("parking").child("nmit").child("3").get()

#Video feed
cap = cv2.VideoCapture('carPark.mp4')

#Open image
with open('CarParkPos','rb') as f:
    posList = pickle.load(f)
    
width, height = 107, 48

def checkParkingSpace(imgPro):
    
    spaceCounter = 0
    for pos in posList:
        x,y=pos
        
        #Finding if a car is present or not usin pixelcount
        imgCrop = imgPro[y:y+height,x:x+width]
        #Showing all the individual parking lots
        #cv2.imshow(str(x*y),imgCrop)
        count = cv2.countNonZero(imgCrop)
        
        #count number in front of the box
        #empty spaces have very low value compared to the occupied ones
        cvzone.putTextRect(img,str(count),(x,y+height-3), scale=1.5, thickness=2, offset=0)
        
        if count < 800:
            color = (0,255,0)
            thickness = 5
            spaceCounter+=1
        else:
            color = (0,0,255)
            thickness = 2
        cv2.rectangle(img, pos, (pos[0]+width,pos[1]+height), color, thickness)
    db.child("parking").child("nmit").child("3").update({"spaces":spaceCounter})
    cvzone.putTextRect(img,f'Free: {spaceCounter}/{len(posList)}',(100,50), scale=4, thickness=5, offset=0, colorR=(0,200,0))
    
while True:
    #Loop it
    if cap.get(cv2.CAP_PROP_POS_FRAMES) == cap.get(cv2.CAP_PROP_FRAME_COUNT):
        cap.set(cv2.CAP_PROP_POS_FRAMES,0)
    success, img = cap.read()
    
    #Thresholding by converting it to grayscale
    imgGray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    imgBlur = cv2.GaussianBlur(imgGray, (3,3), 1)
    imgThreshold = cv2.adaptiveThreshold(imgBlur,255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,25,16)
    #To remove/smoothen the data
    imgMedian = cv2.medianBlur(imgThreshold,5)
    kernel = np.ones((3,3),np.uint8)
    imgDilate = cv2.dilate(imgMedian, kernel, iterations=1)
    
    checkParkingSpace(imgDilate)
    
    #for pos in posList:
        #cv2.rectangle(img, pos, (pos[0]+width,pos[1]+height), (0,0,0), 2)
    
    cv2.imshow("Image",img)
    cv2.imshow("ImageBlur", imgBlur)
    cv2.imshow("ImageThres", imgThreshold)
    cv2.imshow("ImageThres", imgMedian)
    code = cv2.waitKey(1)
    if code == ord('q'):
        break
